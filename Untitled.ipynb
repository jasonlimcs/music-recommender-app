# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("spotify-2023.csv", encoding="ISO-8859-1")
df1.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df1.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df2 = df1.drop(['released_year', 'released_month', 'released_day', 'in_spotify_playlists',
       'in_spotify_charts', 'in_apple_playlists', 'in_apple_charts',
       'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts'], axis=1)
df2.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#      streams  bpm key   mode  danceability_%  valence_%  energy_%  \
# 0  141381703  125   B  Major              80         89        83
# 1  133716286   92  C#  Major              71         61        74
# 2  140003974  138   F  Major              51         32        53
# 3  800840817  170   A  Major              55         58        72
# 4  303236322  144   A  Minor              65         23        80
#
#    acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0              31                   0           8              4
# ...

# %%
df2 = df2[df2['liveness_%']<60]
df2.describe()
# Out:
#        artist_count         bpm  danceability_%   valence_%    energy_%  \
# count    932.000000  932.000000      932.000000  932.000000  932.000000
# mean       1.550429  122.374464       67.063305   51.409871   64.038627
# std        0.893123   28.125473       14.595560   23.563371   16.509562
# min        1.000000   65.000000       23.000000    4.000000    9.000000
# 25%        1.000000   99.000000       57.000000   32.000000   53.000000
# 50%        1.000000  120.000000       69.000000   51.000000   66.000000
# 75%        2.000000  140.000000       78.000000   70.000000   77.000000
# max        8.000000  206.000000       96.000000   97.000000   97.000000
#
#        acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# count      932.000000          932.000000  932.000000     932.000000
# mean        27.018240            1.590129   16.983906      10.197425
# std         26.044098            8.466236   10.976332       9.978692
# ...

# %%
df2.isna().sum()
# Out:
# track_name             0
# artist(s)_name         0
# artist_count           0
# streams                0
# bpm                    0
# key                   92
# mode                   0
# danceability_%         0
# valence_%              0
# energy_%               0
# acousticness_%         0
# instrumentalness_%     0
# liveness_%             0
# speechiness_%          0
# dtype: int64

# %%
df2.shape
# Out:
# (932, 14)

# %%
df2.dropna(inplace=True)
df2.shape
# Out:
# (840, 14)

# %%
df2[df2['instrumentalness_%'] == 0]
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 5                               Sprinter   Dave, Central Cee             2
# ..                                   ...                 ...           ...
# 947                        The Great War        Taylor Swift             1
# 948                         My Mind & Me        Selena Gomez             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df2['streams'] = pd.to_numeric(df2['streams'], errors='coerce')
df2.dropna()
df2.shape
# Out:
# (840, 14)

# %%
import matplotlib.pyplot as plt
plt.scatter(df2['danceability_%'], df2['energy_%'])
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.title('Danceability against Energy')
# Out:
# Text(0.5, 1.0, 'Danceability against Energy')

# %%
top_streamed = df2.nlargest(10, 'streams')
plt.figure(figsize=(10, 6))
plt.barh(top_streamed['track_name'], top_streamed['streams'], color='orange')
plt.title('Top 10 Most Streamed Songs', fontsize=14)
plt.xlabel('Streams', fontsize=12)
plt.ylabel('Track Name', fontsize=12)
plt.gca().invert_yaxis()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df2['bpm'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of BPM (Beats Per Minute)', fontsize=14)
plt.xlabel('BPM', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
plt.figure(figsize=(10, 6))
plt.hist(df2['danceability_%'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Danceability', fontsize=14)
plt.xlabel('Danceability (%)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()
features = [
    'bpm', 'danceability_%', 'valence_%', 'energy_%',
    'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'
]
df2_normalized = pd.DataFrame(scaler.fit_transform(df2[features]), columns=features)

df2_normalized['track_name'] = df2['track_name'].reset_index(drop=True)
df2_normalized['artist(s)_name'] = df2['artist(s)_name'].reset_index(drop=True)

# %%
def recommend_songs(df, input_song, n=5):
    input_song_row = df[df['track_name'].str.lower() == input_song.lower()]
    
    if input_song_row.empty:
        return f"Song '{input_song}' not found in the dataset."
    
    input_features = input_song_row[features].values
    print(input_features)

    similarities = cosine_similarity(input_features, df[features].values).flatten()

    similar_indices = similarities.argsort()[-(n + 1):-1][::-1]

    recommendations = df.iloc[similar_indices][['track_name', 'artist(s)_name']]
    
    return recommendations.reset_index(drop=True)

# %%
input_song = "Blinding Lights"
recommended_songs = recommend_songs(df2_normalized, input_song, n=5)
print(recommended_songs)
# Out:
# [[0.75177305 0.36986301 0.3655914  0.79518072 0.         0.
#   0.10909091 0.08064516]]
#                    track_name                artist(s)_name
# 0                    Chemical                   Post Malone
# 1  Wild Flower (with youjeen)                            RM
# 2   STAY (with Justin Bieber)  Justin Bieber, The Kid Laroi
# 3                 Unstoppable                           Sia
# 4  10 Things I Hate About You                     Leah Kate

# %%
df2_normalized.to_csv("song_data.csv", index=False, header=True)

# %%
df2_normalized[df2_normalized["track_name"]=="Sprinter"]
# Out:
#         bpm  danceability_%  valence_%  energy_%  acousticness_%  \
# 5  0.539007        0.945205   0.666667   0.53012        0.204301
#
#    instrumentalness_%  liveness_%  speechiness_% track_name     artist(s)_name
# 5                 0.0    0.090909       0.354839   Sprinter  Dave, Central Cee

# %%
df2.track_name.to_csv('track_names.csv', index=False)

# %%
df2['tracks'] = df2['track_name'] + ' [' + df2['artist(s)_name'] +']'

# %%
df2.tracks.to_csv('tracks.csv', index=False)
